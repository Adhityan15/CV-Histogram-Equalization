# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Read image in grayscale
img = cv2.imread("test2.jpg", cv2.IMREAD_GRAYSCALE)

if img is None:
    print("Error: Image not found!")
    exit()

# Step 2: Apply Histogram Equalization
equalized = cv2.equalizeHist(img)

# Step 3: Display images
plt.figure(figsize=(10,8))

# Original Image
plt.subplot(2,2,1)
plt.imshow(img, cmap='gray')
plt.title("Original Image")
plt.axis('off')

# Equalized Image
plt.subplot(2,2,2)
plt.imshow(equalized, cmap='gray')
plt.title("Equalized Image")
plt.axis('off')

# Original Histogram
plt.subplot(2,2,3)
plt.hist(img.ravel(), 256, [0,256])
plt.title("Original Histogram")

# Equalized Histogram
plt.subplot(2,2,4)
plt.hist(equalized.ravel(), 256, [0,256])
plt.title("Equalized Histogram")

plt.tight_layout()
plt.show()
# Out:
# C:\Users\adhit\AppData\Local\Temp\ipykernel_2448\2596409733.py:32: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   plt.hist(img.ravel(), 256, [0,256])
# C:\Users\adhit\AppData\Local\Temp\ipykernel_2448\2596409733.py:37: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   plt.hist(equalized.ravel(), 256, [0,256])

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Read image in grayscale
img = cv2.imread("test.jpg", cv2.IMREAD_GRAYSCALE)

if img is None:
    print("Error: Image not found!")
    exit()

# Step 2: Apply Histogram Equalization
equalized = cv2.equalizeHist(img)

# Step 3: Display images
plt.figure(figsize=(10,8))

# Original Image
plt.subplot(2,2,1)
plt.imshow(img, cmap='gray')
plt.title("Original Image")
plt.axis('off')

# Equalized Image
plt.subplot(2,2,2)
plt.imshow(equalized, cmap='gray')
plt.title("Equalized Image")
plt.axis('off')

# Original Histogram
plt.subplot(2,2,3)
plt.hist(img.ravel(), 256, [0,256])
plt.title("Original Histogram")

# Equalized Histogram
plt.subplot(2,2,4)
plt.hist(equalized.ravel(), 256, [0,256])
plt.title("Equalized Histogram")

plt.tight_layout()
plt.show()
# Out:
# C:\Users\adhit\AppData\Local\Temp\ipykernel_2448\2432860207.py:32: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   plt.hist(img.ravel(), 256, [0,256])
# C:\Users\adhit\AppData\Local\Temp\ipykernel_2448\2432860207.py:37: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   plt.hist(equalized.ravel(), 256, [0,256])
